# %%
import torch
from torch import nn
from torch.nn import functional as F

class CenteredLayer(nn.Module):
    def __init__(self):
        super().__init__()
    def forward(self, X):
        return X-X.mean()

# %%
layer = CenteredLayer()
layer(torch.FloatTensor([1,2,3,4,5]))
# Out:
# tensor([-2., -1.,  0.,  1.,  2.])

# %%
net = nn.Sequential(nn.Linear(8, 128), CenteredLayer())

# %%
Y = net(torch.rand(4, 8))
Y.mean()
# Out:
# tensor(4.6566e-09, grad_fn=<MeanBackward0>)

# %%
class MyLinear(nn.Module):
    def __init__(self, in_units, units):
        super().__init__()
        self.myweight = nn.Parameter(torch.rand(in_units, units))
        self.mybias = nn.Parameter(torch.rand(units, ))

    def forward(self, X):
        linear = torch.matmul(X, self.myweight) + self.mybias
        return F.relu(linear)

# %%
dense = MyLinear(5, 3)
dense.myweight
# Out:
# Parameter containing:
# tensor([[0.2011, 0.2613, 0.4144],
#         [0.4295, 0.8542, 0.6101],
#         [0.3472, 0.9560, 0.4946],
#         [0.9982, 0.5486, 0.5743],
#         [0.6757, 0.8661, 0.6392]], requires_grad=True)

# %%
dense(torch.rand(2, 5))
# Out:
# tensor([[1.9120, 2.7579, 1.9180],
#         [1.9961, 2.6571, 2.0515]], grad_fn=<ReluBackward0>)

# %%
net = nn.Sequential(MyLinear(64, 8), MyLinear(8, 1))
net(torch.rand(2, 64))
# Out:
# tensor([[46.8640],
#         [47.3184]], grad_fn=<ReluBackward0>)

# %%
print(net)
# Out:
# Sequential(
#   (0): MyLinear()
#   (1): MyLinear()
# )

# %%
print(net[0].state_dict())
# Out:
# OrderedDict([('myweight', tensor([[0.6763, 0.9285, 0.6650, 0.4379, 0.8160, 0.9833, 0.8908, 0.1153],
#         [0.4434, 0.2526, 0.8612, 0.8973, 0.9209, 0.1105, 0.0112, 0.1107],
#         [0.8394, 0.3208, 0.9308, 0.4441, 0.5919, 0.5947, 0.3682, 0.5327],
#         [0.9144, 0.4309, 0.3892, 0.6737, 0.8484, 0.9908, 0.9117, 0.8884],
#         [0.4068, 0.6723, 0.1192, 0.1207, 0.9574, 0.4091, 0.1627, 0.6301],
#         [0.0984, 0.5851, 0.6725, 0.2058, 0.3099, 0.9555, 0.6498, 0.4833],
#         [0.8902, 0.0149, 0.4872, 0.9073, 0.4683, 0.0861, 0.2122, 0.1248],
#         [0.7613, 0.7016, 0.1263, 0.7739, 0.9175, 0.5732, 0.0743, 0.2472],
#         [0.6960, 0.8611, 0.8251, 0.1119, 0.7616, 0.8704, 0.7637, 0.8231],
#         [0.4605, 0.7099, 0.9542, 0.2153, 0.9965, 0.0847, 0.6976, 0.4207],
#         [0.2057, 0.8186, 0.9140, 0.8425, 0.7280, 0.3020, 0.4794, 0.2164],
#         [0.0909, 0.4875, 0.0313, 0.3445, 0.7926, 0.3310, 0.0520, 0.2793],
#         [0.3166, 0.6520, 0.4516, 0.9304, 0.6566, 0.1378, 0.0855, 0.8555],
#         [0.0359, 0.6958, 0.3160, 0.2821, 0.0708, 0.1507, 0.2465, 0.6812],
#         [0.5875, 0.1640, 0.2222, 0.8523, 0.0145, 0.7115, 0.6715, 0.0410],
#         [0.9911, 0.0167, 0.9640, 0.8356, 0.0923, 0.9786, 0.8973, 0.2514],
#         [0.2960, 0.6646, 0.9393, 0.0349, 0.2783, 0.4586, 0.6595, 0.3065],
#         [0.6275, 0.2099, 0.9940, 0.5133, 0.2537, 0.1293, 0.0157, 0.4419],
#         [0.1775, 0.2362, 0.5430, 0.8702, 0.8131, 0.4937, 0.7695, 0.0336],
#         [0.3440, 0.7407, 0.5446, 0.9106, 0.9310, 0.4942, 0.6041, 0.1650],
#         [0.2873, 0.1119, 0.9267, 0.5778, 0.7013, 0.7670, 0.2807, 0.5015],
#         [0.1390, 0.7112, 0.7149, 0.2487, 0.9460, 0.7627, 0.2419, 0.1617],
#         [0.0797, 0.8599, 0.0530, 0.9594, 0.5613, 0.6191, 0.9789, 0.8407],
#         [0.5403, 0.8567, 0.4977, 0.4655, 0.1026, 0.1450, 0.4193, 0.7908],
#         [0.1949, 0.1333, 0.0253, 0.2956, 0.9206, 0.2262, 0.9950, 0.3941],
#         [0.4504, 0.9389, 0.1380, 0.8398, 0.3518, 0.7227, 0.3523, 0.7785],
#         [0.4634, 0.4314, 0.3727, 0.7174, 0.7630, 0.1434, 0.6871, 0.2350],
#         [0.5086, 0.9915, 0.2152, 0.8972, 0.2303, 0.3056, 0.6605, 0.7458],
#         [0.8118, 0.3582, 0.8898, 0.7011, 0.1679, 0.7786, 0.3576, 0.3675],
#         [0.6411, 0.7014, 0.4129, 0.4554, 0.1536, 0.3170, 0.7050, 0.1640],
#         [0.5738, 0.9573, 0.1788, 0.5410, 0.7633, 0.1782, 0.6795, 0.5895],
#         [0.8347, 0.6242, 0.9394, 0.7126, 0.6366, 0.1465, 0.0294, 0.6607],
#         [0.7200, 0.7117, 0.0824, 0.2544, 0.4666, 0.1469, 0.2749, 0.8268],
#         [0.9698, 0.5343, 0.3997, 0.8429, 0.2830, 0.7837, 0.6709, 0.2629],
#         [0.2280, 0.1828, 0.9352, 0.1201, 0.4146, 0.4985, 0.6106, 0.9628],
#         [0.3597, 0.0711, 0.5861, 0.9759, 0.7752, 0.8462, 0.1567, 0.2933],
#         [0.4097, 0.5919, 0.7843, 0.9034, 0.5955, 0.6365, 0.8810, 0.7384]])), ('mybias', tensor([0.9416, 0.1548, 0.4906, 0.4171, 0.5513, 0.1291, 0.1042, 0.7664]))])
